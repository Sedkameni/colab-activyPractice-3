# %%
### Part 2 - Substring Extraction
## - Print the second word of the string "Learn Python step by step".
sentence = "Learn Python step by step"
print("The second word of the string above is:", sentence[6:12]) #.split()[1]
# Out:
# The second word of the string above is: Python

# %%
### - Extract and print the substring "science" from the string "Data science is interesting".
new_sentence = "Data science is interesting"
substring = new_sentence[5:12]
print(substring)
# Out:
# science

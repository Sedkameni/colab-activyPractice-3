# %%
## Part 1 - String Concatenation
### - Concatenate the strings "Hello", "world", and "2024" using the '+' operator.

H = "Hello"
W = "world"
Y = "2024"

print("The concatenated string is:", H + " " + W + " " + Y)
# Out:
# The concatenated string is: Hello world 2024

# %%
## - Use an f-string to concatenate and format the same strings into a sentence.

print(f"The concatenated string is: {H} {W} {Y}")
# Out:
# The concatenated string is: Hello world 2024

# %%
## - Join the strings ["data", "science", "is", "awesome"] with a space separator using the join method.
sentence = " ".join(["data", "science", "is", "awesome"])
print(sentence)
# Out:
# data science is awesome

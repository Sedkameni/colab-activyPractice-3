# %%
a=5

# %%
b=6

# %%
a==b
# Out:
# False

# %%
if a==5 and b < 2:
  print("I am going to school")
else:
    print("I am home")
# Out:
# I am home

# %%
def toto(x,y):
  a=8
  b = a + x - 17*y
  return b

# %%
print("The value of the above function is:", toto(20,39))
print("My a is:", a)
# Out:
# The value of the above function is: -635
# My a is: 5

# %%
import cmath
#import math
n = 100

for i in range(n):
  a= cos(2*pi*i/n)
  b = sin(2*pi*i/n)
  #a + b j
  print(a, b)
  if i == 5:
    break
# Out:
# 1.0 0.0
# 0.9980267284282716 0.06279051952931337
# 0.9921147013144779 0.12533323356430426
# 0.9822872507286887 0.1873813145857246
# 0.9685831611286311 0.2486898871648548
# 0.9510565162951535 0.3090169943749474

# %%
i=0
n=100
while i < n:
  a= cos(2*pi*i/n)
  b = sin(2*pi*i/n)
  #a + b j
  print(a, b)
  i = i + 1
# Out:
# 1.0 0.0
# 0.9980267284282716 0.06279051952931337
# 0.9921147013144779 0.12533323356430426
# 0.9822872507286887 0.1873813145857246
# 0.9685831611286311 0.2486898871648548
# 0.9510565162951535 0.3090169943749474
# 0.9297764858882515 0.3681245526846779
# 0.9048270524660196 0.42577929156507266
# 0.8763066800438636 0.4817536741017153
# 0.8443279255020151 0.5358267949789967
# 0.8090169943749475 0.5877852522924731
# 0.7705132427757893 0.6374239897486896
# 0.7289686274214116 0.6845471059286886
# 0.6845471059286886 0.7289686274214116
# 0.6374239897486897 0.7705132427757893
# 0.5877852522924732 0.8090169943749473
# 0.5358267949789965 0.8443279255020151
# 0.48175367410171516 0.8763066800438637
# 0.42577929156507266 0.9048270524660196
# 0.3681245526846781 0.9297764858882513
# 0.30901699437494745 0.9510565162951535
# 0.24868988716485474 0.9685831611286311
# 0.18738131458572474 0.9822872507286886
# 0.12533323356430448 0.9921147013144778
# 0.06279051952931353 0.9980267284282716
# ...

# %%
Z1 = 0.9980267284282716 + 0.06279051952931337 j

# %%
T=('a','b')

# %%
T.append('c')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2453049020.py in <cell line: 0>()
# ----> 1 T.append('c')
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
T=['a','b']

# %%
T.append('c')

# %%
print(T)
# Out:
# ['a', 'b', 'c']

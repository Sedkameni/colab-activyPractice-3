# %%
#### Part 7 - String Searching
### - Use the index method to find the starting index of the substring "Python" in the string "Learn Python step by step".
sentence = "Learn Python step by step"
print("The starting index of the substring \"python\" is:", sentence.index("Python"))
# Out:
# The starting index of the substring "python" is: 6

# %%
### - Use the find method to find the starting index of the substring "programming" in the string "Python programming is fun".
sentence1 = "Python programming is fun"
print("The starting index of the substring \"programming\" is:", sentence1.find("programming"))
# Out:
# The starting index of the substring "programming" is: 7

# %%
### - Use the count method to count the occurrence of the substring "is" in the string "This is a test. This is only a test."
text = "This is a test. This is only a test."
print("\nThe number of occurence of \'is\' in the string is:", text.count("is"))
# Out:
# The number of occurence of 'is' in the string is: 4

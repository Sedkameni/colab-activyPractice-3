# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# !unzip -o /content/datasets.zip
from google.colab import files
uploaded=files.upload() # select datasets.zip from your computer
# Out:
# Archive:  /content/datasets.zip
#    creating: datasets/
#   inflating: datasets/csv_mindex.csv
#   inflating: datasets/diabetes.csv
#   inflating: datasets/ex1.xlsx
#   inflating: datasets/ex2.csv
#   inflating: datasets/ex3.csv
#   inflating: datasets/ex3.txt
#   inflating: datasets/ex4.csv
#   inflating: datasets/ex5.csv
#   inflating: datasets/ex6.csv
#   inflating: datasets/ex7.csv
#   inflating: datasets/example.json
#   inflating: datasets/out.csv
#   inflating: datasets/sample_sales_data.xlsx
#   inflating: datasets/stock_px.csv
#   inflating: datasets/test.tsv
#   inflating: datasets/test_file.csv
#   inflating: datasets/Titanic-Dataset.csv
#   inflating: datasets/tseries.csv
#      <input type="file" id="files-29d0c72e-35e4-420e-a875-a778c8afef72" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-29d0c72e-35e4-420e-a875-a778c8afef72">
#       Upload widget is only available when the cell has been executed in the
# ...

# %%
import os #Imports Python’s os module, which lets you interact with the operating system — like checking files, folders, and paths.
# Unzip dataset if it exists
if os.path.exists("datasets.zip"):
    # !unzip -o datasets.zip
    print("Datasets unzipped successfully.")
else:
    print("datasets.zip not found in folder.")
# Out:
# Archive:  datasets.zip
#   inflating: datasets/csv_mindex.csv
#   inflating: datasets/diabetes.csv
#   inflating: datasets/ex1.xlsx
#   inflating: datasets/ex2.csv
#   inflating: datasets/ex3.csv
#   inflating: datasets/ex3.txt
#   inflating: datasets/ex4.csv
#   inflating: datasets/ex5.csv
#   inflating: datasets/ex6.csv
#   inflating: datasets/ex7.csv
#   inflating: datasets/example.json
#   inflating: datasets/out.csv
#   inflating: datasets/sample_sales_data.xlsx
#   inflating: datasets/stock_px.csv
#   inflating: datasets/test.tsv
#   inflating: datasets/test_file.csv
#   inflating: datasets/Titanic-Dataset.csv
#   inflating: datasets/tseries.csv
# Datasets unzipped successfully.

# %%
# List CSV files
csv_files = [f for f in os.listdir() if f.endswith(".csv")]
print("CSV files available:", csv_files)
# Out:
# CSV files available: ['datasetLab.csv', 'patients.csv']

# %%
#Load the first CSV as example
# list of csv’s files?????
import pandas as pd
if csv_files:
    df = pd.read_csv(csv_files[0])
    print("First 5 rows of", csv_files[0])
    print(df.head())
else:
    print("No CSV files found")
# Out:
# First 5 rows of datasetLab.csv
#                                                 text
# 0  I love this movie! It's fantastic and well-acted.
# 1  This product is terrible. I would not recommen...
# 2    The service was okay, but the food was amazing!
# 3  I am so disappointed with this purchase. Waste...
# 4  Absolutely wonderful experience. Would buy again!

# %% [markdown]
# ## Fundamentals of Python

# %%
# integers
a = 7
print("fggdgsgd" + str(a))
# Out:
# fggdgsgd7

# %%
x = 10
y = 5.5
name = "Lab 3 Python Refresher"
is_open = True

print(x, y, name, is_open)
# Out:
# 10 5.5 Lab 3 Python Refresher True

# %%
# Conditional logic
if is_open:
    print("Lab is ready")
else:
    print("Lab not ready")
# Out:
# Lab is ready

# %%
# Loop example
for i in range(3):
    print(f"Iteration {i+1}, Even? {i%2==0}")
# Out:
# Iteration 1, Even? True
# Iteration 2, Even? False
# Iteration 3, Even? True

# %%
# !git init
# !git config --global user.name "Sedkameni"
# !git config --global user.email "sedrick.kameni@gmail.com"
# !git remote -v
# !git remote set-url origin https://github.com/Sedkameni/colab-activyPractice-3.git
# !git add Sedrick_Lab3_IAI.ipynb
# !git commit -m "Commit 1: Fundamentals of Python"
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/Colab Notebooks/.git/
# origin	https://github.com/Sedkameni/colab-activyPractice-3.git (fetch)
# origin	https://github.com/Sedkameni/colab-activyPractice-3.git (push)
# [master c76340c] Commit 1: Fundamentals of Python
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# Save the dataset to a new CSV file
df.to_csv("patients.csv", index=False)
# Read it back to verify
df_csv = pd.read_csv("patients.csv")
print(df_csv.head())
# Out:
#                                                 text
# 0  I love this movie! It's fantastic and well-acted.
# 1  This product is terrible. I would not recommen...
# 2    The service was okay, but the food was amazing!
# 3  I am so disappointed with this purchase. Waste...
# 4  Absolutely wonderful experience. Would buy again!

# %%
import pickle

# Save the DataFrame
with open("patients.pkl", "wb") as f:
    pickle.dump(df, f)

# Load the DataFrame back from the pickle file
with open("patients.pkl", "rb") as f:
    df_pickle = pickle.load(f)

# Now you can safely print it
print(df_pickle.head())
# Out:
#                                                 text
# 0  I love this movie! It's fantastic and well-acted.
# 1  This product is terrible. I would not recommen...
# 2    The service was okay, but the food was amazing!
# 3  I am so disappointed with this purchase. Waste...
# 4  Absolutely wonderful experience. Would buy again!

# %%
import sqlite3

# Connect to (or create) database
conn = sqlite3.connect("patients.db")
cursor = conn.cursor()
# Save DataFrame to SQLite table
df.to_sql("patients", conn, if_exists="replace", index=False)
# Out:
# 10

# %%
# Query first 5 rows from database
df_sql = pd.read_sql("SELECT * FROM patients LIMIT 5", conn)
print(df_sql)
# Close connection
conn.close()
# !git add Lesson_3_Lab_python_refresher.ipynb
# !git commit -m "Commit 3: File I/O, Pickle, and SQLite database operations
# Out:
#                                                 text
# 0  I love this movie! It's fantastic and well-acted.
# 1  This product is terrible. I would not recommen...
# 2    The service was okay, but the food was amazing!
# 3  I am so disappointed with this purchase. Waste...
# 4  Absolutely wonderful experience. Would buy again!
# /bin/bash: -c: line 1: unexpected EOF while looking for matching `"'
# /bin/bash: -c: line 2: syntax error: unexpected end of file

# %%
# --- Use Case: Taking User Input to Check BMI in Dataset ---

# Ask the user to input a BMI value
user_bmi = input("Enter a BMI value to check: ")
#name = input("Enter your name: ")
#age = input(int("Enter your age: "))
# Out:
# Enter a BMI value to check: ii

# %%
# import all the similar files, csv's

import zipfile
import os

# Path to your datasets zip
zip_path = "datasets.zip"

# Check if the zip file exists
if os.path.exists(zip_path):
    print("datasets.zip found.")

    # List all CSV files inside the zip (without extracting)
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        csv_files_in_zip = [f for f in zip_ref.namelist() if f.endswith('.csv')]
        print("CSV files inside datasets.zip:")
        for file in csv_files_in_zip:
            print(" -", file)

    # Extract all files
    # !unzip -o datasets.zip -d datasets
    print("\n Files extracted successfully to 'datasets' folder.")
# List CSV files after extraction
    extracted_csvs = [f for f in os.listdir('datasets') if f.endswith('.csv')]
    print("\n CSV files available after extraction:")
    for file in extracted_csvs:
        print(" -", file)

else:
    print(" datasets.zip not found in this folder.")
# Out:
# datasets.zip found.
# CSV files inside datasets.zip:
#  - datasets/csv_mindex.csv
#  - datasets/diabetes.csv
#  - datasets/ex2.csv
#  - datasets/ex3.csv
#  - datasets/ex4.csv
#  - datasets/ex5.csv
#  - datasets/ex6.csv
#  - datasets/ex7.csv
#  - datasets/out.csv
#  - datasets/stock_px.csv
#  - datasets/test_file.csv
#  - datasets/Titanic-Dataset.csv
#  - datasets/tseries.csv
# Archive:  datasets.zip
#   inflating: datasets/datasets/csv_mindex.csv
#   inflating: datasets/datasets/diabetes.csv
#   inflating: datasets/datasets/ex1.xlsx
#   inflating: datasets/datasets/ex2.csv
#   inflating: datasets/datasets/ex3.csv
#   inflating: datasets/datasets/ex3.txt
#   inflating: datasets/datasets/ex4.csv
#   inflating: datasets/datasets/ex5.csv
#   inflating: datasets/datasets/ex6.csv
#   inflating: datasets/datasets/ex7.csv
#   inflating: datasets/datasets/example.json
#   inflating: datasets/datasets/out.csv
#   inflating: datasets/datasets/sample_sales_data.xlsx
# ...

# %%
# !mkdir -p /content/colab-activyPractice-3
# %cd /content/colab-activyPractice-3
# Out:
# /content/colab-activyPractice-3

# %%
# !git init
# !git remote remove origin  # optional, only if you had one already

USERNAME = "Sedkameni"
REPO = "colab-activyPractice-3"

# !git remote add origin https://{USERNAME}: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@github.com/{USERNAME}/{REPO}.git
# !git remote -v
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/colab-activyPractice-3/.git/
# error: No such remote: 'origin'
# origin	https://Sedkameni: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@github.com/Sedkameni/colab-activyPractice-3.git (fetch)
# origin	https://Sedkameni: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@github.com/Sedkameni/colab-activyPractice-3.git (push)

# %%
# !git push origin main

# %%
# !cp "/content/drive/MyDrive/Colab Notebooks/Sedrick_Lab3_IAI.ipynb" /content/colab-activyPractice-3/
# Out:
# cp: cannot create regular file '/content/colab-activyPractice-3/': Not a directory

# %%
# %cd /content/colab-activyPractice-3
# Out:
# [Errno 2] No such file or directory: '/content/colab-activyPractice-3'
# /content/drive/MyDrive/Colab Notebooks

# %%
# %cd /content/colab-activyPractice-3

# !git remote remove origin  # remove the broken one

USERNAME="Sedkameni"
REPO="colab-activyPractice-3"  # the name of your GitHub repo

# !git remote add origin https://{USERNAME}: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@github.com/{USERNAME}/{REPO}.git

# !git remote -v
# Out:
# [Errno 2] No such file or directory: '/content/colab-activyPractice-3'
# /content/drive/MyDrive/Colab Notebooks
# origin	https://Sedkameni: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@github.com/Sedkameni/colab-activyPractice-3.git (fetch)
# origin	https://Sedkameni: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@github.com/Sedkameni/colab-activyPractice-3.git (push)

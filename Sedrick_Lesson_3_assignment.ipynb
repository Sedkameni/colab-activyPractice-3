# %% [markdown]
# #### **ATTENTION!!!**
# - **Place each section (1,2...) in one or more cells to keep the notebook organised**
# - **Complete the codes in the `TODO` sections**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# Python Library Management System

# Install required libraries (This should already exist in colab)
# !pip install requests

import pickle
import sqlite3
import requests

# 1. Data Types and Variables
book_title = "Python Programming"
book_quantity = 5
book_price = 29.99
is_available = True

print(f"Book: {book_title}, Quantity: {book_quantity}, Price: ${book_price}, Available: {is_available}")
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2025.10.5)
# Book: Python Programming, Quantity: 5, Price: $29.99, Available: True

# %%
# 2. Lists
books = ["Python Basics", "Advanced Python", "Data Science with Python"]

# TODO: Add two more books to the list
# books.append(...)
books.append("Machine Learning")
# books.insert(...)
books.insert(0, "Deep Learning")

print("Updated book list:", books)
# Out:
# Updated book list: ['Deep Learning', 'Python Basics', 'Advanced Python', 'Data Science with Python', 'Machine Learning']

# %%
# 3. Loops and range()
print("\nAvailable books:")
# TODO: Use a for loop and range() to print books with their indices
for i in range(len(books)):
    print(f"{i}: {books[i]}")
# Out:
# Available books:
# 0: Deep Learning
# 1: Python Basics
# 2: Advanced Python
# 3: Data Science with Python
# 4: Machine Learning

# %%
# 4. User Input
new_book = input("Enter a new book title: ")
books.append(new_book)
print("Updated book list:", books)
# Out:
# Enter a new book title: Analysis
# Updated book list: ['Deep Learning', 'Python Basics', 'Advanced Python', 'Data Science with Python', 'Machine Learning', 'Analysis']

# %%
# 5. Functions and Conditional Statements
def check_availability(book_name):
    # TODO: Check if the book is in the list and return True if available, False otherwise
    if book_name in books:
        return True
    else:
        return False

    pass

# Test the function
print(f"Is 'Python Basics' available? {check_availability('Python Basics')}")
# Out:
# Is 'Python Basics' available? True

# %%
# 6. File I/O
def save_books_to_file(filename):
    with open(filename, 'w') as f:
        for book in books:
            f.write(f"{book}\n")

# TODO: Implement a function to read books from a file
def read_books_from_file(filename):
    with open(filename, 'r') as f:
        return f.read().splitlines()

# Test file I/O
save_books_to_file("books.txt")
# !cat books.txt  # Display file contents in Colab
# Out:
# Deep Learning
# Python Basics
# Advanced Python
# Data Science with Python
# Machine Learning
# Analysis

# %%
# 7. Pickle for serialization
def save_books_pickle(filename):
    with open(filename, 'wb') as f:
        pickle.dump(books, f)

# TODO: Implement a function to load books using pickle
def load_books_pickle(filename):
    with open(filename, 'rb') as f:
        return pickle.load(f)

# Test pickle functions
save_books_pickle("books.pkl")
# Uncomment the next line after implementing load_books_pickle
print("Books loaded from pickle:", load_books_pickle("books.pkl"))
# Out:
# Books loaded from pickle: ['Deep Learning', 'Python Basics', 'Advanced Python', 'Data Science with Python', 'Machine Learning', 'Analysis']

# %%
# 8. SQLite Database Interaction
def create_books_table():
    conn = sqlite3.connect('library.db')
    cursor = conn.cursor()
    cursor.execute('''CREATE TABLE IF NOT EXISTS books
                      (id INTEGER PRIMARY KEY, title TEXT, quantity INTEGER)''')
    conn.commit()
    conn.close()

# TODO: Implement a function to add a book to the SQLite database
def add_book_to_db(title, quantity):
    conn = sqlite3.connect('library.db')
    cursor = conn.cursor()
    cursor.execute("INSERT INTO books (title, quantity) VALUES (?, ?)", (title, quantity))
    conn.commit()
    conn.close()

# Test database functions
create_books_table()
# Uncomment the next line after implementing add_book_to_db
add_book_to_db("Python for Beginners", 10)

# %%
# 9. Web API Interaction (GitHub API)
def get_python_repos():
    url = "https://api.github.com/search/repositories"
    params = {"q": "language:python", "sort": "stars", "order": "desc"}
    response = requests.get(url, params=params)
    data = response.json()
    return [repo['name'] for repo in data['items'][:5]]

# Test API function
print("Top 5 Python repositories on GitHub:", get_python_repos())

print("\nLibrary Management System operations completed.")
# Out:
# Top 5 Python repositories on GitHub: ['free-programming-books', 'public-apis', 'system-design-primer', 'awesome-python', 'Python']
#
# Library Management System operations completed.

# %%
# !git init
# !git config --global user.name "Sedkameni"
# !git config --global user.email "sedrick.kameni@gmail.com"
# !git remote -v
# !git remote set-url origin https://github.com/Sedkameni/colab-activyPractice-3.git
# !git add Sedrick_Lesson_3_assignment.ipynb
# !git commit -m "Commit 1: Fundamentals of Python"
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/Colab Notebooks/.git/
# origin	https://github.com/Sedkameni/colab-activyPractice-3.git (fetch)
# origin	https://github.com/Sedkameni/colab-activyPractice-3.git (push)
# [master 547b37c] Commit 1: Fundamentals of Python
#  1 file changed, 1 insertion(+)
#  create mode 100644 Sedrick_Lesson_3_assignment.ipynb

# %%
# !cp /content/drive/MyDrive/Colab\ Notebooks/Sedrick_Lesson_3_assignment.ipynb .
# Out:
# cp: '/content/drive/MyDrive/Colab Notebooks/Sedrick_Lesson_3_assignment.ipynb' and './Sedrick_Lesson_3_assignment.ipynb' are the same file

# %%
# !git init
# !git remote remove origin  # optional, only if you had one already

USERNAME = "Sedkameni"
REPO = "colab-activyPractice-3"

# !git add Sedrick_Lesson_3_assignment.ipynb
# !git commit -m "Commit 1: Fundamentals of Python"
# !git remote add origin https://{USERNAME}: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@github.com/{USERNAME}/{REPO}.git
# !git remote -v
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/Colab Notebooks/.git/
# [main 6225a4a] Commit 1: Fundamentals of Python
#  1 file changed, 1 insertion(+), 1 deletion(-)
# origin	https://Sedkameni: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@github.com/Sedkameni/colab-activyPractice-3.git (fetch)
# origin	https://Sedkameni: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@github.com/Sedkameni/colab-activyPractice-3.git (push)

# %%
# !git pull origin main --allow-unrelated-histories
# Out:
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 3 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (3/3), 7.27 KiB | 137.00 KiB/s, done.
# From https://github.com/Sedkameni/colab-activyPractice-3
#  * branch            main       -> FETCH_HEAD
#  * [new branch]      main       -> origin/main
# hint: You have divergent branches and need to specify how to reconcile them.
# hint: You can do so by running one of the following commands sometime before
# hint: your next pull:
# hint:
# hint:   git config pull.rebase false  # merge (the default strategy)
# hint:   git config pull.rebase true   # rebase
# hint:   git config pull.ff only       # fast-forward only
# hint:
# hint: You can replace "git config" with "git config --global" to set a default
# hint: preference for all repositories. You can also pass --rebase, --no-rebase,
# hint: or --ff-only on the command line to override the configured default per
# hint: invocation.
# fatal: Need to specify how to reconcile divergent branches.

# %%
# !git config pull.rebase true
# !git pull origin main
# Out:
# error: cannot pull with rebase: You have unstaged changes.
# error: please commit or stash them.

# %%
# !git push origin main
# Out:
# To https://github.com/Sedkameni/colab-activyPractice-3.git
#  ! [rejected]        main -> main (non-fast-forward)
# error: failed to push some refs to 'https://github.com/Sedkameni/colab-activyPractice-3.git'
# hint: Updates were rejected because the tip of your current branch is behind
# hint: its remote counterpart. Integrate the remote changes (e.g.
# hint: 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.

# %%
# !git branch -M main
# !git push origin main
# Out:
# To https://github.com/Sedkameni/colab-activyPractice-3.git
#  ! [rejected]        main -> main (fetch first)
# error: failed to push some refs to 'https://github.com/Sedkameni/colab-activyPractice-3.git'
# hint: Updates were rejected because the remote contains work that you do
# hint: not have locally. This is usually caused by another repository pushing
# hint: to the same ref. You may want to first integrate the remote changes
# hint: (e.g., 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.

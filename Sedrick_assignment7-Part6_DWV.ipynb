# %%
#### Part 6 - String Replacement
###Replace the word "bad" with "good" in the string "This is a bad example".
string = "This is a bad example"
new_string = string.replace("bad","good")
print(new_string)
# Out:
# This is a good example
